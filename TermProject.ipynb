# %% [markdown]
# ### 라이브러리 목록

# %%
import urllib.request 
import requests
from urllib.request import urlopen
from bs4 import BeautifulSoup
import selenium

from selenium import webdriver as wb
import time
import re

# %% [markdown]
# ### CatchesFashion으로부터 인기브랜드 목록 가져오기

# %%
options = wb.ChromeOptions()
options.add_argument('headless')
options.add_argument('window-size=1920x1080')
options.add_argument("disable-gpu")

driver = wb.Chrome('C:/Users/kion9/Desktop/2020-2학기/웹파이썬프로그래밍/term_project/chromedriver',chrome_options=options)
driver.implicitly_wait(3)

driver.get('https://www.catchfashion.com/men/brands')
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')
pop_brand = []
elems = soup.find_all('img', class_='logo')
for brands in elems:
    pop_brand.append(brands['alt'])
    if(len(pop_brand)==24):
        break
'''
brands = soup.find('div', class_='sc-oUmCr bMisCU')
#for b in brands:
 #   brandPre = b.find('div',class_='sc-fzoCUK kBjMiw font_secondaryRegular__2O8hV Typography_UntitledSansR14__1rNws')
  #  brand = brandPre.text
   # pop_brand.append(brand)
'''
print()

pop_brand = sorted(pop_brand)
pop_brand
# Out:
# ['A.P.C.',
#  'Acne Studios',
#  'Balenciaga',
#  'Bottega Veneta',
#  'Burberry',
#  'Gucci',
#  'Lemaire',
#  'Loewe',
#  'Maison Kitsuné',
#  'Maison Margiela',
#  'Marni',
#  'PRADA',
#  'Saint Laurent',
#  'Stone Island']

# %% [markdown]
# ## 각 사이트 별로 브랜드 목록 가져오기

# %% [markdown]
# ### 1. Matchesfashion

# %%
#Matchesfashion | https://www.matchesfashion.com/kr/mens/bags?noattraqt=set
matches_brand = []
'''
options = wb.ChromeOptions()
options.add_argument('headless')
options.add_argument('window-size=1920x1080')
options.add_argument("disable-gpu")
'''
driver = wb.Chrome('C:/Users/kion9/Desktop/2020-2학기/웹파이썬프로그래밍/term_project/chromedriver')
driver.implicitly_wait(3)
driver.get('https://www.matchesfashion.com/kr/mens/designers')
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')


elems = soup.find_all('a', class_='designeraz__list__item tooltipstered')
for brands in elems:
    brand = brands.get_text()
    matches_brand.append(brand)
    
matches_brand = sorted(matches_brand)
matches_brand
# Out:
# ['1 MONCLER JW ANDERSON',
#  '100%',
#  '1017 ALYX 9SM',
#  '11.11 / eleven eleven ',
#  '1882 x Faye Toogood',
#  '2 MONCLER 1952',
#  '2XU',
#  '3 MONCLER GRENOBLE',
#  '424',
#  '5 MONCLER CRAIG GREEN',
#  '6 MONCLER1017 ALYX 9SM',
#  '66°North',
#  '7 Days Active',
#  '7 MONCLER FRAGMENT HIROSHI FUJIWARA',
#  '73 London',
#  'A-COLD-WALL*',
#  'A.P.C.',
#  'AMI',
#  'ANOTHER ASPECT',
#  'Acne Studios',
#  'Adidas',
#  'Adidas X Craig Green',
#  'Adidas X Wales Bonner',
#  'Adieu',
#  'Adish',
#  'Aerin',
#  'Ahluwalia',
#  'Alan Crocetti',
#  'Albam',
#  'Albus Lumen',
#  'Aldo Maria Camillo',
#  'Alexander McQueen',
#  'Alighieri',
#  'Alison Lousada',
#  'Alister Mackie',
#  'All Blues',
#  'Allude',
#  'Altea',
#  'Amen Candles',
#  'Amiri',
#  'Ancient Greek Sandals',
#  'And Wander',
#  "Anderson's",
#  'Andy Wolf',
#  'Angela Wickstead',
#  'Anissa Kermiche',
#  'Ann Demeulemeester',
#  'Anna Karlin',
#  'Anya Hindmarch',
#  'Apnee',
#  'Aries',
#  'Armani, Giorgio',
#  'Armogan',
#  'Arnar Mar Jonsson',
#  'Ashish',
#  'Ashmei',
#  'Asics',
#  'Athletic Propulsion Labs',
#  'Aztech Mountain',
#  'Balenciaga',
#  'Balmain',
#  'Bao Bao Issey Miyake',
#  'Barena Venezia',
#  'Bed J.W. Ford',
#  'Begg x Co',
#  'Bella Freud',
#  'Belstaff',
#  'Berluti',
#  'Bianca Saunders',
#  'Billionaire Boys Club',
#  'Birkenstock',
#  'Bleue Burnham',
#  'Blue Carreon',
#  'Bode',
#  'Bogner',
#  'Bogner Golf',
#  'Bonastre',
#  'Boramy Viguier',
#  'Bordallo Pinheiro',
#  'Borsalino',
#  'Bottega Veneta',
#  'Bourrienne Paris X',
#  'Brunello Cucinelli',
#  'Burberry',
#  'By Walid',
#  'C.P. Company',
#  'CAMPERLAB',
#  'CDLP',
#  'Cabana Magazine',
#  'Café Du Cycliste',
#  'Calvin Klein Performance',
#  'Calvin Klein Underwear',
#  'Campbell Rey',
#  'Canada Goose',
#  'Capranea',
#  'Carl Auböck',
#  'Cartier Eyewear',
#  'Caruso',
#  'Casablanca',
#  'Castañer',
#  'Castore',
#  'Castore Golf',
#  'Castore Tennis',
#  'Celine Eyewear',
#  'Charles Jeffrey Loverboy',
#  'Cheaney',
#  'Christian Louboutin',
#  'Christina Lundsteen',
#  'Christopher Kane',
#  "Church's",
#  'Ciele Athletics',
#  'Cinnamon Projects',
#  'Cire Trudon',
#  'Cleverly Laundry',
#  'Commas',
#  'Comme Des Garçons Shirt',
#  'Comme des Garçons Wallet',
#  'Common Projects',
#  'Completedworks',
#  'Converse',
#  'Craig Green',
#  'Crash Baggage',
#  "D'Ascoli",
#  'DSquared²',
#  'Deakin & Francis',
#  'Dear Letterman',
#  'Denis Colomb',
#  'Dents',
#  'Derek Rose',
#  'Descente Allterrain',
#  'Desmond & Dempsey',
#  'Deveaux',
#  'Diemme',
#  'Dinosaur Designs',
#  'Dior Homme Sunglasses',
#  'District Vision',
#  'Dita Eyewear',
#  'Dolce & Gabbana',
#  'Dr Martens',
#  'Dunhill',
#  'E. Tautz',
#  'EYEVAN 7285',
#  'Eastpak',
#  'Eckhaus Latta',
#  'Edward Crutchley',
#  'Edward Green',
#  'Ellie Mercer',
#  'Emanuele Bicocchi',
#  'Emilio Pucci',
#  'Emma Willis',
#  'Endless Joy',
#  'Equipment',
#  'Espelma',
#  'Etro',
#  'Evian by Virgil Abloh',
#  'Eytys',
#  'F. Hammann',
#  'FEAROFGODZEGNA',
#  'FPM Milano',
#  'Falke',
#  'Falke Ess',
#  'Falke Ess Cycling',
#  'Falke Ess Golf',
#  'Fear Of God',
#  'Feldspar',
#  'Fendi',
#  'Fernando Jorge',
#  'Flatlist',
#  'Floyd',
#  'Folk',
#  'Fornasetti',
#  'Frame',
#  'Fred Eyewear',
#  'Frescobol Carioca',
#  'Frette',
#  'Fusalp',
#  'G.H. Bass & Co.',
#  'GOLDWIN',
#  'Gabriela Hearst',
#  'Garrett Leight',
#  'Georgia Kemball',
#  'Gergei Erdei',
#  'Giles Deacon',
#  'Ginori 1735',
#  'Giorgio Armani',
#  'Givenchy',
#  'Globe-Trotter',
#  'GmbH',
#  'Golden Goose',
#  'Goya',
#  'Gramicci',
#  'Greg Lauren',
#  'Grenson',
#  'Guanabana',
#  'Gucci',
#  'Guidi',
#  'HARAGO',
#  'Haider Ackermann',
#  'Hamilton and Hare',
#  'Hanro',
#  'Harris Wharf London',
#  'Hector Saxe',
#  'Helle Mardahl',
#  'Helly Hansen',
#  'Helmut Lang',
#  'Hemen Biarritz',
#  'Hereu',
#  'Herno',
#  'Holden',
#  'Homme Plissé Issey Miyake',
#  'Horizn Studios',
#  'Horror Vacui',
#  'House of Hackney',
#  "Howlin'",
#  'Hunting Season',
#  'Iffley Road',
#  'Inabo',
#  'Incotex',
#  'Inis Meáin',
#  'Innovators',
#  'Iris Von Arnim',
#  'Isabel Marant',
#  'Issey Miyake Men',
#  'J.Lindeberg',
#  'J.W. Brine',
#  'JW Anderson',
#  'Jacob Cohën',
#  'Jacquemus',
#  'Jacques',
#  'Jacques Marie Mage',
#  'Jacques Solovière',
#  'Jeanerica Jeans & Co.',
#  'Jil Sander',
#  'John Booth',
#  'John Elliott',
#  'John Lobb',
#  'Johnstons Of Elgin',
#  'Jonathan Hansen x Marie Daâge',
#  'Junya Watanabe',
#  'KASK',
#  'KJUS',
#  'Kassl Editions',
#  'Kilometre Paris',
#  'King & Tuckfield',
#  'Kjus Golf',
#  'Klättermusen',
#  'Ksubi',
#  'Kuboraum',
#  'L.E.J',
#  'L.G.R. Sunglasses',
#  'LNDR',
#  'La DoubleJ',
#  'Laboratorio Paravicini',
#  'Lady White',
#  'Lahgo',
#  'Larsson & Jennings',
#  'Lauren Manoogian',
#  'Le Gramme',
#  'Le Sirenuse Positano',
#  'Lemaire',
#  'Les Ottomans',
#  'Les Tien',
#  'Lily Pearmain',
#  'Lisa Corti',
#  'Lizzie Mandler',
#  'Lobmeyr',
#  'Lock & Co. Hatters',
#  'Loewe',
#  "Loewe Paula's Ibiza",
#  'London Sock Company',
#  'London Undercover',
#  'Lorenzi Milano',
#  'Loretta Caponi',
#  'Lost Daze',
#  'Louboutin, Christian',
#  'Ludovic de Saint Sernin',
#  'Luis Morais',
#  'Luisa Beccaria',
#  'Luke Edward Hall',
#  'Lululemon',
#  'Lutz Morris',
#  'L’Objet',
#  'L’Officine Universelle Buly 1803',
#  'M Cohen',
#  'Mackintosh',
#  'Maison Kitsuné',
#  'Maison Margiela',
#  'Mammut Delta X',
#  'Manebí',
#  'Marané',
#  'Marie Lichtenberg',
#  'Marine Serre',
#  'Mario Sorrenti',
#  'Mark Cross',
#  'Marni',
#  "Marques'Almeida",
#  'Marrakshi Life',
#  'Marsèll',
#  'Marta Ferri',
#  'Martine Ali',
#  'Martine Rose',
#  'Master & Dynamic',
#  'Matchesfashion',
#  'Matilda Goad',
#  'Matsuda',
#  'Miansai',
#  'Michaël Verheyden',
#  'Mihara Yasuhiro',
#  'Mismo',
#  'Missoni',
#  'Missoni Mare',
#  'Moncler',
#  'Moncler + Rick Owens',
#  'Moncler Genius',
#  'Moncler Grenoble',
#  'Montelliana',
#  'More Joy by Christopher Kane',
#  'Mulo',
#  'Mykita',
#  'Métier',
#  'Namacheko',
#  'Nanushka',
#  'Nathalee Paolinelli',
#  'Native Union',
#  'Needles',
#  'Neil Barrett',
#  'Nemen',
#  'Neuw ',
#  'New Balance',
#  'Nick Fouquet',
#  'Nick Vinson',
#  'Nina Nørgaard',
#  'Nipoaloha',
#  'Nobis',
#  'Noma t.d.',
#  'Noon Goons',
#  'Norrøna',
#  'Nosakhari',
#  'Odyssee',
#  'Officine Générale',
#  'Oliver Peoples',
#  'Oliver Spencer',
#  'On',
#  'Once Milano',
#  'Onia',
#  'Organic Basics',
#  'Orlebar Brown',
#  'Our Legacy',
#  'Overose',
#  'O’Keeffe',
#  'P. Le Moult',
#  'Paco Rabanne',
#  'Palm Angels',
#  'Pantherella',
#  'Paravel',
#  'Parts of Four',
#  'Paul Smith',
#  'Peak Performance',
#  'Pearls Before Swine',
#  'Pendleton',
#  'Pendleton Yoga',
#  'Perfect Moment',
#  'Perfumer H',
#  'Peter Pilotto',
#  'Phipps',
#  'Pineider',
#  'Polo Ralph Lauren',
#  'Post-Imperial',
#  'Prada',
#  'Preen By Thornton Bregazzi',
#  'Primury',
#  'Péro',
#  'Quoddy',
#  'R+D.LAB',
#  'ROA',
#  'RRL',
#  'Raawii',
#  'Rabitti 1969',
#  'Raey',
#  'Raf Simons',
#  'Raf Simons X Eastpak',
#  'Rag & Bone',
#  'Ralph Lauren Golf',
#  'Ralph Lauren Purple Label',
#  'Ralph Lauren, Polo',
#  'Reebok',
#  'Reflections Copenhagen',
#  'Reigning Champ',
#  'Richard Brendon',
#  'Richard Quinn',
#  'Rick Owens',
#  'Rick Owens DRKSHDW',
#  'SEKFORD',
#  'SMR Days',
#  'SOAR',
#  'Saint Laurent',
#  'Salomon',
#  'Santoni',
#  'Sasquatchfabrix.',
#  'Satisfy',
#  'Saturdays NYC',
#  'Saved New York',
#  'Schiesser',
#  'Sease',
#  'Sekford Watches',
#  'Serapis Maritime',
#  'Serax x Ann Demeulemeester',
#  'Seya',
#  'Shaun Leane',
#  'Shay',
#  'Simone Bodmer-Turner',
#  'Smythson',
#  'Snow Peak',
#  'Socksss',
#  'Sorel',
#  'South2 West8',
#  'Spinelli Kilcollin',
#  'Stefan Cooke',
#  'Stepney Workers Club',
#  'Stone Island',
#  'Stone Island Shadow Project',
#  'Studio Nicholson',
#  'Suicoke',
#  'Summerill & Bishop',
#  'Sun Buddies',
#  'Sunflower',
#  'Sunspel',
#  'Séfr',
#  'TAKAHIROMIYASHITA TheSoloist.',
#  'Tekla',
#  'Templa',
#  'The Elder Statesman',
#  'The Gigi',
#  'The Lacquer Company',
#  'The North Face',
#  'The North Face Flight Series',
#  'The North Face Summit Series',
#  'The Row',
#  'The Salvages',
#  'The Wolseley Collection ',
#  'Themis Z',
#  'Thom Browne',
#  'Thom Sweeney',
#  'Thorsun',
#  'Tibor',
#  "Tod's",
#  'Toga Virilis',
#  'Tom Ford Eyewear',
#  'Tom Wood',
#  'Toni Sailer',
#  'Toogood',
#  "Tricker's",
#  'Troubadour',
#  'Umit Benan B+',
#  'Undercover',
#  'Valentino',
#  'Valextra',
#  'Vanessa Mitrani',
#  'Veilance',
#  'Veja',
#  'Venetia Berry',
#  'Versace',
#  'Vetements',
#  'Vilebrequin',
#  'Wales Bonner',
#  'Walter Van Beirendonck',
#  'Want Les Essentiels',
#  'Wedel Art Collective',
#  'Wooyoungmi',
#  'Y-3',
#  'Y/Project',
#  'YMC',
#  'YNIQ',
#  'Yali Glass',
#  'Yuketen',
#  'ZdG',
#  'Zeal Optics',
#  'Zimmerli',
#  'Álvaro']

# %% [markdown]
# ### 2. Farfetch

# %%
#Farfetch | https://www.farfetch.com/kr/shopping/men/items.aspx
farfetch_brand = []
options = wb.ChromeOptions()
options.add_argument('headless')
options.add_argument('window-size=1920x1080')
options.add_argument("disable-gpu")
driver = wb.Chrome('C:/Users/kion9/Desktop/2020-2학기/웹파이썬프로그래밍/term_project/chromedriver',chrome_options=options)
driver.implicitly_wait(3)
driver.get('https://www.farfetch.com/kr/designers/men')
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')
brandsFar = soup.find_all('li', class_='_3d4abb _a99adf')
for b in brandsFar:
    farfetch_brand.append(b.get_text())

farfetch_brand
# Out:
# ['A BATHING APE®',
#  'A COLD WALL',
#  'A Diciannoveventitre',
#  'A Kind of Guise',
#  'À La Garçonne',
#  'A New Cross',
#  'A-COLD-WALL*',
#  'A.A. Spectrum',
#  'A.N.G.E.L.O. Vintage Cult',
#  'A.P.C.',
#  'A.W.A.K.E. Mode',
#  'A(Lefrude)E',
#  'AAPE BY *A BATHING APE®',
#  'Abasi Rosborough',
#  'Acne Studios',
#  'Adaptation',
#  'Addict Clothes Japan',
#  'Ader',
#  'Ader Error',
#  'adidas',
#  'adidas by 032c',
#  'adidas by 424',
#  'adidas by Craig Green',
#  'adidas by Kolor',
#  'adidas by Pharrell Williams',
#  'adidas by Raf Simons',
#  'adidas by Stella McCartney',
#  'adidas by White Mountaineering',
#  'adidas Kids',
#  'adidas Originals',
#  'adidas Originals by Alexander Wang',
#  'adidas x Wings + Horns',
#  'adidas YEEZY',
#  'Adieu Paris',
#  'Adish',
#  'Affix',
#  'AG Jeans',
#  'AGE',
#  'agnès b. ',
#  'AGR',
#  'Ahlem',
#  'Ahluwalia',
#  'Aiezen',
#  'Ajmone',
#  'Al Duca D’Aosta 1902',
#  'Alain Mikli',
#  'Alan Crocetti',
#  'Alanui',
#  'Alberto Fasciani',
#  'Alchemist',
#  'Alchemy',
#  'Aleksandr Manamïs',
#  'Ales Grey',
#  'Alessandro Gherardi',
#  'Alessi',
#  'Alex Mill',
#  'Alexander McQueen',
#  'Alexander McQueen Eyewear',
#  'Alexander Wang',
#  'Alexandra Llewellyn',
#  'Alighieri',
#  'Alk Phenix',
#  'All Blues',
#  'all in',
#  'Ally Capellino',
#  'Alpha Industries',
#  'Alpina',
#  'Altea',
#  'Amapô',
#  'AMBUSH',
#  'Amen',
#  'AMI AMALIA',
#  'AMI Paris',
#  'Amir Slama',
#  'AMIRI',
#  'Ancient Greek Sandals',
#  'and Wander',
#  'Andersen-Andersen',
#  "Anderson's",
#  'Andrea Crews',
#  "Andrea Ya'aqov",
#  'Andreas Kronthaler For Vivienne Westwood',
#  'Andy Wolf',
#  'Anglepoise',
#  'Anglozine',
#  'Anke Drechsel',
#  'Ann Demeulemeester',
#  'Ann Demeulemeester Grise',
#  'Ann Demeulemeester Icon',
#  'Anna Karlin',
#  'Annelise Michelson',
#  'Annoushka',
#  'Anon',
#  'ANONYMOUS ISM',
#  'Anti Social Social Club',
#  'Anya Hindmarch',
#  'Anya Hindmarch Smells',
#  'APL: ATHLETIC PROPULSION LABS',
#  'Apparis',
#  'Aquascutum Vintage',
#  "Arc'teryx",
#  'Archive Eyewear',
#  'Aries',
#  'Arkk',
#  'Armani Collezioni',
#  'Armani Exchange',
#  'Armani Jeans',
#  'Army Of Me',
#  'Art School',
#  'Artel',
#  'Artica Arbox',
#  'Artselab',
#  'As2ov',
#  'Ash',
#  'ASICS',
#  'Asics x Vivienne Westwood',
#  'Aspesi',
#  'Assouline',
#  'Astorflex',
#  'Astrid Andersen',
#  'Athletics Footwear',
#  'Atlantic Stars',
#  'Atm Anthony Thomas Melillo',
#  'Attachment',
#  'Au Depart',
#  'Au Départ',
#  'Audemars Piguet',
#  'Auralee',
#  'AUTRY',
#  'Auxiliary',
#  'AV Vattev',
#  'Avant Toi',
#  'Axel Arigato',
#  'AYTM',
#  'Aztech Mountain',
#  'B-Used',
#  'Babylon LA',
#  'Backes & Strauss',
#  'Bagnoli Sartoria Napoli',
#  'Bagutta',
#  'Baldinini',
#  'Balenciaga',
#  'Balenciaga Eyewear',
#  'Ballantyne',
#  'Bally',
#  'Balmain',
#  'Balmain Eyewear',
#  'Balmain Pre-Owned',
#  'Bamford Watch Department',
#  'Band of Outsiders',
#  'Bang & Olufsen',
#  'Bao Bao Issey Miyake',
#  'Baobab Collection',
#  'Barba',
#  'Barbour',
#  'Barena',
#  'Barrett',
#  'Barrie',
#  'BARROW',
#  'Barton Perreira',
#  'BasShu',
#  'Battenwear',
#  'Baudoin & Lange',
#  'BE ABLE',
#  'BEAR',
#  'Bed J.W. Ford',
#  'Bell & Ross',
#  'Bellerose',
#  'Belstaff',
#  'Bergfabel',
#  'Bering',
#  'Bernhard Willhelm',
#  'Berwich',
#  'Bethany Williams',
#  'Billionaire',
#  'Billionaire Boys Club',
#  'Billy Los Angeles',
#  'Birkenstock',
#  'Biro',
#  'BITOSSI CERAMICHE',
#  'Bitossi Home',
#  'Black & Brown',
#  'Black Comme Des Garçons',
#  'Blackbarrett',
#  'Blancpain',
#  'Blauer',
#  'Bleue Burnham',
#  'Blood Brother',
#  'Blueflag + Kiminori Morishita',
#  'Bluemint',
#  'Blyszak',
#  'Bmuet(Te)',
#  'BODE',
#  'Boglioli',
#  'Bohinc Studio',
#  'Bonpoint',
#  'Bontoni',
#  'Boramy Viguier',
#  'Boris Bidjan Saberi',
#  'BornxRaised',
#  'Borrelli',
#  'BOSS',
#  'Boss Hugo Boss',
#  'BOSS Kidswear',
#  'Both',
#  'Bottega Veneta',
#  'Bottega Veneta Eyewear',
#  'Botter',
#  'Boucheron',
#  'Boutique Moschino',
#  'Brain Dead',
#  'Brandblack',
#  'Braun Watches',
#  'Breguet',
#  'Breitling',
#  'Bremont',
#  'Briglia 1949',
#  'Brimarts',
#  'Brioni',
#  'Briston Watches',
#  'Browns',
#  'Brumal',
#  'Brunello Cucinelli',
#  'Buffalo',
#  'Bulgari Pre-Owned',
#  'Bunney',
#  'Burberry',
#  'Burberry Eyewear',
#  'Burberry Pre-Owned',
#  'Burton',
#  'Burton AK',
#  'Buscemi',
#  'Buttero',
#  'Bvlgari',
#  'By Walid',
#  'Byborre',
#  'C.P. Company',
#  'C.P. Company',
#  'C.P. Company Kids',
#  'C.P. Company Pre-Owned',
#  'C2h4',
#  'Caban',
#  'Cabas',
#  'Calvin Klein',
#  'Calvin Klein 205W39nyc',
#  'Calvin Klein Jeans',
#  'Calvin Klein Jeans Est. 1978',
#  'Calvin Klein Underwear',
#  'Camiel Fortgens',
#  'Camilla',
#  'Camper',
#  'CamperLab',
#  'Canada Goose',
#  'Canali',
#  'Canessa',
#  'Capricode',
#  'Car Shoe',
#  'Careering',
#  'Carhartt',
#  'Carhartt WIP',
#  'Cariuma',
#  'Carlo Moretti',
#  'Carpe Diem',
#  'Carrera',
#  'Carrera Junior',
#  'Cartier',
#  'Cartier',
#  'Cartier Eyewear',
#  'Caruso',
#  'Carvil',
#  'Casablanca',
#  'Casey Casey',
#  'Castañer',
#  'Castro Smith',
#  'Cavalli Class',
#  'Cazal',
#  'CDLP',
#  'Cecchi De Rossi',
#  'Cédric Charlier',
#  'Cedric Jacquemyn',
#  'Celine Eyewear',
#  'Céline Pre-Owned',
#  'Cenere GB',
#  'Cerruti 1881',
#  'Cesare Paciotti',
#  'Chalayan',
#  'Champion',
#  'Chanel Pre-Owned',
#  'Chaos',
#  'Charles Jeffrey Loverboy',
#  'Cherevichkiotvichki',
#  'Children Of The Discordance',
#  'Chinatown Market',
#  'Chloé Eyewear',
#  'Chopard Eyewear',
#  'Chopard Pre-Owned',
#  'Christian Dada',
#  'Christian Dior',
#  'Christian Koban',
#  'Christian Pellizzari',
#  'Christian Roth',
#  'Christian Roth Eyewear',
#  'Christian Wijnants',
#  'Christopher Kane',
#  'Chronoswiss',
#  "Church's",
#  'Cinzia Araia',
#  'Circolo 1901',
#  'Cire Trudon',
#  'Citizens of Humanity',
#  'CK Calvin Klein',
#  'Claire Goldsmith',
#  'Clarks Originals',
#  'Closed',
#  'CLOT',
#  'Cmmn Swdn',
#  'Coach',
#  'Cobra S.C.',
#  'Cody Sanderson',
#  'college',
#  'Colmar',
#  'Colmar A.G.E. By Shayne Oliver',
#  'Colombo',
#  'Comme Des Garçons',
#  'Comme Des Garçons Homme',
#  'Comme Des Garçons Homme Plus',
#  'Comme Des Garçons Play',
#  'COMME DES GARÇONS PLAY X CONVERSE',
#  'Comme Des Garçons Pre-Owned',
#  'Comme Des Garçons Shirt',
#  'Comme Des Garçons Shirt Boys',
#  'Comme Des Garçons Tricot',
#  'Comme Des Garçons Wallet',
#  'Common Projects',
#  'Converse',
#  'Converse x JW Anderson',
#  'Coohem',
#  'COOL T.M',
#  'Corelate',
#  'Cornelian Taurus By Daisuke Iwanaga',
#  'Corneliani',
#  'Corum',
#  'Costumein',
#  'Côte&Ciel',
#  'Cottweiler',
#  'Coup De Coeur',
#  'Courrèges Eyewear',
#  'Courrèges Pre-Owned',
#  'CP COMPANY',
#  'Craig Green',
#  'Crocs',
#  'Cruciani',
#  'Cuisse de grenouille',
#  'Cult',
#  'Curieux',
#  'Curionoir',
#  'Cutler & Gross',
#  'D.A.T.E.',
#  "D'urban",
#  'D1 Milano',
#  'Daily Paper',
#  'Damir Doma',
#  'Daniel Andresen',
#  'Daniel Patrick',
#  'Daniele Alessandrini',
#  'Danner',
#  'Danton',
#  'DARKAI',
#  'Dashiel Brahmann',
#  'David Catalan',
#  'David Yurman',
#  'De Beers',
#  'De Grisogono',
#  'Del Carlo',
#  'Delada',
#  'Delantic',
#  'Delfina Delettrez',
#  "Dell'oglio",
#  'Department 5',
#  'Deperlu',
#  'Derek Rose',
#  'Desa 1972',
#  'Desa Collection',
#  'Descente Allterrain',
#  'Desmond & Dempsey',
#  'Destin',
#  'Detaj',
#  'Deus Ex Machina',
#  'Devoa',
#  'Di Liborio',
#  'Diadora',
#  'DICKIES',
#  'Dickies Construct',
#  'Diemme',
#  'Diesel',
#  'Diesel Black Gold',
#  'Diesel Red Tag',
#  'Dima Leu',
#  'Dimissianos & Miller',
#  'Dior Eyewear',
#  'Dirk Bikkembergs',
#  'Discord Yohji Yamamoto',
#  'District Vision',
#  'Dita Eyewear',
#  'DKNY',
#  'Dolce & Gabbana',
#  'Dolce & Gabbana Eyewear',
#  'Dolce & Gabbana Pre-Owned',
#  'DOMREBEL',
#  "Don't Worry",
#  'Dondup',
#  'Doriani Cashmere',
#  'Doublet',
#  "Doucal's",
#  'Dr. Martens',
#  'Drôle De Monsieur',
#  'Drome',
#  'Drumohr',
#  'Dsquared2',
#  'Dsquared2 Beachwear',
#  'Dsquared2 Eyewear',
#  'Dsquared2 Kids',
#  'Dsquared2 Underwear',
#  'Duffy Jewellery',
#  'DUOltd',
#  'DUST',
#  'Duvetica',
#  'Dyne',
#  'E. Tautz',
#  'E30022',
#  'Ea7 Emporio Armani',
#  'Each X Other',
#  'Eastpak',
#  'eastpak by raf simons',
#  'Eastpak x Raf Simons',
#  'Eckhaus Latta',
#  'Ecoalf',
#  'Ed Robert Judson',
#  'Edhen Milano',
#  'Editions Milano',
#  'Edward Crutchley',
#  'Edwin',
#  'Egrey',
#  'El Casco',
#  'Eleventy',
#  'Elie Saab',
#  'Emanuel Ungaro Pre-Owned',
#  'Emanuele Bicocchi',
#  'Emilio Pucci',
#  'Emilio Pucci Pre-Owned',
#  'Emporio Armani',
#  'Endless Joy',
#  'Enfants Riches Déprimés',
#  'Engineered For Motion',
#  'Engineered Garments',
#  'Entre Amis',
#  'Epos',
#  'EQUE.M',
#  'Equipment',
#  'Eredi Chiarini',
#  'ERL',
#  'Ermanno Gallamini',
#  'Ermenegildo Zegna',
#  'Ermenegildo Zegna XXX',
#  'Ernest W. Baker',
#  'Established & Sons',
#  'Etnia Barcelona',
#  'Eton',
#  'Etro',
#  'Etudes',
#  'Evan Kinori',
#  'Evangelisti World',
#  'Ewing',
#  'Ex Infinitas',
#  'Extreme Cashmere',
#  'Eyepetizer',
#  'Eyevan7285',
#  'Eyewear by David Beckham',
#  'Eytys',
#  'F_WD',
#  'F.A.M.T.',
#  'Fabric Brand & Co',
#  'Face À Face',
#  'Facetasm',
#  'Factotum',
#  'Faith Connexion',
#  'Fake Alpha Vintage',
#  "Fake Alpha X Levi's Vintage",
#  'Faliero Sarti',
#  'Falke',
#  'Family Affair',
#  'Family First',
#  'Fashion Clinic Timeless',
#  'Favre Leuba',
#  'Fay',
#  'Fear Of God',
#  'FEAROFGODZEGNA',
#  'Fedeli',
#  'Federico Curradi',
#  'Fendi',
#  'Fendi Eyewear',
#  'Fendi Pre-Owned',
#  'Feng Chen Wang',
#  'FENTY',
#  'Fenty X Puma',
#  'Fferrone Design',
#  'Fila',
#  'Fileria',
#  'Filippa K',
#  'Filling Pieces',
#  'Filson',
#  'Finamore 1925 Napoli',
#  'Fiorentini +  Baker',
#  'Fiorucci',
#  'FIVE CM',
#  'Floyd',
#  'Fob Paris',
#  'Folk',
#  'Forcerepublik',
#  'Forme D’expression',
#  'Formy Studio',
#  'Fornasetti',
#  'Fornasetti Profumi',
#  'FPM Milano',
#  'FRAME',
#  'Frame Chain',
#  'Francesco Russo',
#  'Frankie Morello',
#  'Fratelli Rossetti',
#  'Fred',
#  'Fred Perry',
#  'Fred Perry X Art Comes First',
#  'Frédérique Constant',
#  'Freemans Sporting Club',
#  'Frenckenberger',
#  'Frency & Mercury',
#  'Frescobol Carioca',
#  'Fumito Ganryu',
#  'Furla',
#  'Fürstenberg',
#  'Fusalp',
#  'G-Shock',
#  'G-Star RAW',
#  'G-Star Raw Research',
#  'G.H. Bass & Co.',
#  'Gabriele Pasini',
#  'GALLERY DEPT.',
#  'Garbage Tv',
#  'Garçons Infidèles',
#  'Garrett Leight',
#  'Gas Bijoux',
#  'Gavello',
#  'Gcds',
#  'Gentle Monster',
#  'Geo',
#  'Geoffrey Parker',
#  'Georg Jensen',
#  'Geym',
#  'Ghoud',
#  'Gianfranco Ferré Pre-Owned',
#  'Gianvito Rossi',
#  'Gieves & Hawkes',
#  'GINORI 1735',
#  'Giorgio Armani',
#  'Giorgio Armani Pre-Owned',
#  'Giorgio Brato',
#  'Girard Perregaux',
#  'Gitman Vintage',
#  'Giuliano Galiano',
#  'Giuseppe Zanotti',
#  'Givenchy',
#  'Givenchy Eyewear',
#  'Givenchy Pre-Owned',
#  'Glanshirt',
#  'Gloverall',
#  'GmbH',
#  "God's Masterful Children",
#  'Gold And Wood',
#  'Golden Goose',
#  'Golden Goose Kids',
#  'Good News',
#  'goodboy',
#  'Goodfight',
#  'Goose Tech',
#  'Goossens',
#  'Gosha Rubchinskiy',
#  'Goti',
#  'Gouverneur Audigier',
#  'GR-Uniforma',
#  'GR10K',
#  'Gramicci',
#  'Green George',
#  'Greg Lauren',
#  'Greg Lauren X Paul & Shark',
#  'Grenson',
#  'Grey Ant',
#  'Griffin',
#  'Ground Zero',
#  'Gucci',
#  'Gucci Eyewear',
#  'Gucci Pre-Owned',
#  'Guidi',
#  'Guy Laroche Pre-Owned',
#  'Hackett',
#  'Haculla',
#  'Haffmans & Neumeister',
#  'Haider Ackermann',
#  'Haikure',
#  'Han Kjøbenhavn',
#  'Hand Picked',
#  'Handred',
#  'Hands on design',
#  'Harmony Paris',
#  'Harris Wharf London',
#  'Harrys of London',
#  'Hatton Labs',
#  'Hay',
#  'Hed Mayner',
#  'HELIOT EMIL',
#  'Helly Hansen',
#  'Helmut Lang',
#  'Helmut Lang Pre-Owned',
#  'Hender Scheme',
#  'Henderson Baracco',
#  'Henrik Vibskov',
#  'Henson',
#  'Hermès',
#  'Herno',
#  'Heron Preston',
#  'Herrlicht',
#  'Herschel Supply Co.',
#  'Hevo',
#  'Hi-Tec HTS74',
#  'Hide&Jack',
#  'Hilfiger Collection',
#  'Hl Heddie Lovu',
#  'Hogan',
#  'Hogan Rebel',
#  'Hoka One One',
#  'Holiday',
#  'Holland & Holland',
#  'Holzpuppe',
#  'Homme Plissé Issey Miyake',
#  'Homme Plissé\xa0Issey Miyake',
#  'Honey Fucking Dijon',
#  'HONOR THE GIFT',
#  'Hood By Air',
#  'Horizn Studios',
#  'HORUS WATCH STRAPS',
#  "Howlin'",
#  'Htc Los Angeles',
#  'Hublot',
#  'HUGO',
#  'Hum',
#  'Hunting Season',
#  'Hydrogen',
#  'Hyein Seo',
#  'HYT',
#  'Ic! Berlin',
#  'Iceberg',
#  'Icosae',
#  'Iffley Road',
#  'Ih Nom Uh Nit',
#  'Iise',
#  'IIUVO',
#  'Ileana Makri',
#  'Ill.I',
#  'Incarnation',
#  'Incentive! Cashmere',
#  'Incotex',
#  'Indispensable',
#  'Individual Sentiments',
#  'Inês Torcato',
#  'Ingersoll Watches',
#  'Ink',
#  'Innerraum',
#  'Intoxicated',
#  'Iris Von Arnim',
#  'Iroquois',
#  'Irresistor',
#  'Isaac Reina',
#  'Isaac Sellam Experience',
#  'Isabel Benenato',
#  'Isabel Marant',
#  'Isaia',
#  'Islang',
#  'Issey Miyake',
#  'Issey Miyake Men',
#  'Issey Miyake Pre-Owned',
#  'Italia Independent',
#  'IWC Schaffhausen',
#  'izzue',
#  'J Brand',
#  'J Lindeberg',
#  "J.Hill's Standard",
#  'J.Lindeberg',
#  'Jacob Cohen',
#  'Jacob Cohen Academy',
#  'Jacque Marie Mage',
#  'Jacqueline Rabun',
#  'Jacquemus',
#  'Jacques Marie Mage',
#  'Jaeger-LeCoultre',
#  'James Perse',
#  'Jan Jan Van Essche',
#  'JC de Castelbajac Pre-Owned',
#  'Jean Paul Gaultier Pre-Owned',
#  'Jeanerica',
#  'Jil Sander',
#  'Jil Sander Pre-Owned',
#  'Jimmy Choo',
#  'Jimmy Choo Eyewear',
#  'Joe Chia',
#  'John Elliott',
#  'John Galliano',
#  'John Hardy',
#  'John Lobb',
#  'John Richmond',
#  'John Richmond Junior',
#  'John Smedley',
#  'John Varvatos',
#  'John Varvatos Star Usa',
#  'JohnUNDERCOVER',
#  'Jordan',
#  'JORDAN LUCA',
#  'Jorg Hysek',
#  'Josef Miller',
#  'Joseph',
#  'Joshua Sanders',
#  'JOY BC',
#  'Julien David',
#  'Julius',
#  'Junya Watanabe',
#  'Junya Watanabe Comme des Garçons Pre-Owned',
#  'Junya Watanabe MAN',
#  "Junya Watanabe Man X Levi's",
#  'Just Cavalli',
#  'Just Don',
#  'Juun.J',
#  'Jvdf',
#  'JW Anderson',
#  'K-WAY R&D',
#  'Kaleos',
#  'Kame Mannen',
#  'KANGHYUK',
#  'Kansai Yamamoto Pre-Owned',
#  'Kanye West',
#  'Kapital',
#  'Kappa',
#  'Kappa Kontroll',
#  'Kara',
#  'Karen Chekerdjian Studio',
#  'Karen Walker',
#  'Karhu',
#  'Karl Lagerfeld',
#  'Kasun London',
#  'Kate Cate',
#  'Kate Spade',
#  'Katharine Hamnett London',
#  'KAWS',
#  'Kazuyuki Kumagai',
#  'Keiser Clark',
#  'Kenneth Ize',
#  'Kent & Curwen',
#  'Kenzo',
#  'Kenzo Pre-Owned',
#  'Khrisjoy',
#  'Kidill',
#  'Kids of broken future',
#  'Kiko Kostadinov',
#  'King Baby',
#  'Kired',
#  'Kirin',
#  'Kiton',
#  'KJUS',
#  'Klättermusen',
#  'Koché',
#  'Koio',
#  'Kolor',
#  'Komakino',
#  'Ksubi',
#  'KTZ',
#  'Kuboraum',
#  'KYme',
#  'Kyme Junior',
#  'L.G.R',
#  "L'Eclaireur Made By",
#  "L'Objet",
#  'L&Jr',
#  'La Doublej',
#  "La Fileria For D'aniello",
#  'La Petite Lunette Rouge',
#  'La Seine & Moi',
#  'Lacoste',
#  'Lacoste Live',
#  'Lady Anne',
#  'Lamberto Losani',
#  'Laneus',
#  'LANVIN',
#  'Lardini',
#  'LAUD',
#  'Laura Lombardi',
#  'LC23',
#  'Le Gramme',
#  'Le Kasha',
#  'Le Specs',
#  'Leclaireur',
#  'Leisure Society',
#  'Lemaire',
#  'LeQarant',
#  'LERET LERET',
#  'Les (Art)Ists',
#  'Les Benjamins',
#  'Les Hommes',
#  'Les Hommes Urban',
#  'Les Tien',
#  'Lesca',
#  "Levi's",
#  "Levi's Vintage Clothing",
#  "Levi's: Made & Crafted",
#  'Li-Ning',
#  'Liam Hodges',
#  'Liberaiders',
#  'Liberal Youth Ministry',
#  'Lidfort',
#  'Limitato',
#  'Linda Farrow',
#  'Lindberg',
#  'Linder',
#  'LIQUIPROOF',
#  'Lisa Von Tang',
#  'Liska',
#  'LIU JO',
#  'Lloyd',
#  'LOEWE',
#  'Longchamp',
#  'Lorenzi Milano',
#  'Loro Piana',
#  'Lost & Found Ria Dunn',
#  'Lost Daze',
#  'Lotos',
#  'Lou Dalton',
#  'Louis Leeman',
#  'Louis Vuitton',
#  'LOUIS VUITTON',
#  'Lourdes ',
#  'Love Moschino',
#  'Low Brand',
#  'LSA International',
#  'Ludovic De Saint Sernin',
#  'Luigi Borrelli',
#  'Lunor',
#  'Luv Collections',
#  'Lygia & Nanny',
#  'Lyly Erlandsson',
#  'M Missoni',
#  'M. Cohen',
#  'M.Cohen',
#  "Ma'ry'ya",
#  'MAAP',
#  'Mackage',
#  'Mackintosh',
#  'Mackintosh 0002',
#  'Mackintosh 0003',
#  'Mackintosh 0004',
#  'Mad Et Len',
#  'MAD Paris',
#  'Mads Nørgaard',
#  'magis',
#  'Magliano',
#  'Magnanni',
#  'Maharishi',
#  'Maison Close',
#  'Maison Flaneur',
#  'Maison Kitsuné',
#  'Maison Margiela',
#  'Maison Martin Margiela Pre-Owned',
#  'Maison Mihara Yasuhiro',
#  'Maison Recuerdo',
#  'Majestic Filatures',
#  'Makavelic',
#  'MALIN+GOETZ',
#  'Mallet',
#  'Malo',
#  'Malone Souliers',
#  'Mammut',
#  'Manebi',
#  'Manokhi',
#  'Manuel Ritz',
#  'Manzoni 24',
#  'Marc Jacobs',
#  'Marc Jacobs Eyewear',
#  'Marcelo Burlon County of Milan',
#  'MARCH LA.B',
#  'Marco De Vincenzo',
#  'Marcoliani',
#  'Maria Black',
#  'Marine Serre',
#  'Mark Cross',
#  'Marni',
#  'Marni Eyewear',
#  'MARNI INTERIORS',
#  'Marni Market',
#  'Marsèll',
#  'Marshall',
#  'Martine Rose',
#  'MASAHIROMARUYAMA',
#  'Masnada',
#  'Massada',
#  'Massimo Alba',
#  'Master & Dynamic',
#  'Mastercraft Union',
#  'Mastermind Japan',
#  'Mastermind World',
#  'Mastermind World X Adidas',
#  'Masunaga',
#  'Matiéres',
#  'Matsuda',
#  'MATT MORO',
#  'Matthew Miller',
#  'Matthew Williamson',
#  'Maui Jim',
#  'Mauna Kea',
#  'Maurice Lacroix',
#  'Maurizio Miri',
#  'Mauro Grifoni',
#  'Max Mara',
#  'Mazzarelli',
#  'Mazzucato',
#  'Mc2 Saint Barth',
#  'MCM',
#  'MCQ',
#  'McQ Swallow',
#  'Meadowlark',
#  'Medicom Toy',
#  'Menu',
#  'Merrell',
#  'Michael Kors',
#  'Michael Kors Collection',
#  'Michael Michael Kors',
#  'Michael Verheyden',
#  'Midnight Studios',
#  'migos',
#  'Mindseeker',
#  'Minimalux',
#  'MISBHV',
#  'Mismo',
#  'Missoni',
#  'MISSONI EYEWEAR',
#  'Missoni Home',
#  'Missoni Mare',
#  'Missoni Pre-Owned',
#  'Miu Miu Eyewear',
#  'Miu Miu Pre-Owned',
#  'Mizuno',
#  'MJB Marc Jacques Burton',
#  'MM6 Maison Margiela',
#  'Moa Master Of Arts',
#  'Moma',
#  'Moncler',
#  'Moncler + Rick Owens',
#  'Moncler Eyewear',
#  'Moncler Gamme Bleu',
#  'Moncler Genius 1952',
#  'Moncler Genius x Craig Greene',
#  'Moncler Grenoble',
#  'Moncler Kids',
#  'Moncler x Poldo',
#  'Monica Vinader',
#  'Monocle Eyewear',
#  'Monse',
#  'Montblanc',
#  'Moohong',
#  'Moorer',
#  'Moose Knuckles',
#  'More Joy',
#  'Moschino',
#  'Moschino Eyewear',
#  'Moschino Pre-Owned',
#  'Moscot',
#  'Mostly Heard Rarely Seen',
#  'Mostly Heard Rarely Seen 8-Bit',
#  'Mother',
#  'Motherlan',
#  'Mou',
#  'Moussy Vintage',
#  'Mowalola',
#  'MP Massimo Piombo',
#  'Mr & Mrs Italy',
#  'Mr Jones',
#  'Mr. Completely',
#  'MSGM',
#  'Mulberry',
#  'Myar',
#  'Mykita',
#  'MYKITA+MAISON MARGIELA',
#  'Myths',
#  'N. Hoolywood',
#  'N.Peal',
#  'N/A',
#  ...]

# %% [markdown]
# ### 3. SSENSE

# %%
#ssense | https://www.ssense.com/en-us/men
ssense_brand = []
driver = wb.Chrome('C:/Users/kion9/Desktop/2020-2학기/웹파이썬프로그래밍/term_project/chromedriver')
driver.implicitly_wait(3)
driver.get('https://www.ssense.com/en-us/men')
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

brands = soup.find_all('span', class_='s-text s-text--font-family-inter')
for b in brands:
    ssense_brand.append(b.get_text())
for i in range(4):
    ssense_brand.pop()
ssense_brand
# Out:
# ['032c',
#  '1017 ALYX 9SM',
#  '11 by Boris Bidjan Saberi',
#  '132 5. ISSEY MIYAKE',
#  '3.1 Phillip Lim',
#  '3MAN',
#  '424',
#  '49Winters',
#  '4SDESIGNS',
#  '99% IS',
#  'A-COLD-WALL*',
#  'A. A. Spectrum',
#  'A.P.C.',
#  'Acne Studios',
#  'ACRONYM',
#  'ADER error',
#  'adidas Originals',
#  'adidas Originals by Alexander Wang',
#  'adidas Originals x Pharrell Williams',
#  'adidas x Human Made',
#  'adidas x IVY PARK',
#  'adidas x Missoni',
#  'ADYAR',
#  'Affix',
#  'Afterhomework',
#  'AGR',
#  'Ahluwalia',
#  'Aimé Leon Dore',
#  'Aitor Throup’s TheDSA',
#  'Alan Crocetti',
#  'Alanui',
#  'Alchemist',
#  'Alexander McQueen',
#  'Alexander Wang',
#  'All Blues',
#  'all in',
#  'ALMOSTBLACK',
#  'Ambush',
#  'AMI Alexandre Mattiussi',
#  'AMIRI',
#  'Andersson Bell',
#  'Ann Demeulemeester',
#  'Aries',
#  'Arnar Már Jónsson',
#  'Article No.',
#  'Asics',
#  'Athletics Footwear',
#  'AURALEE',
#  'Awake NY',
#  'Axel Arigato',
#  'Balenciaga',
#  'Balmain',
#  'Bao Bao Issey Miyake',
#  'BAPE',
#  'Barbour',
#  'Barena',
#  'Bather',
#  'BEAMS PLUS',
#  'BED J.W. FORD',
#  'Belstaff',
#  'Benjamin Edgar',
#  'Bethany Williams',
#  'Bianca Saunders',
#  'Billionaire Boys Club',
#  'Billy',
#  'Blackmerle',
#  'Bless',
#  'Bleue Burnham',
#  'Blue Blue Japan',
#  'Bode',
#  'Boramy Viguier',
#  'Boris Bidjan Saberi',
#  'Boss',
#  'both',
#  'Bottega Veneta',
#  'Botter',
#  'Brain Dead',
#  'Brioni',
#  'Burberry',
#  'By Walid',
#  'Byredo',
#  'C.P. Company',
#  'C2H4',
#  'Calvin Klein 205W39NYC',
#  'Calvin Klein Jeans Est. 1978',
#  'Calvin Klein Underwear',
#  'Camiel Fortgens',
#  'CamperLab',
#  'Canada Goose',
#  'Carhartt Work In Progress',
#  'Carlota Barrera',
#  'Carne Bollente',
#  'Casablanca',
#  'Castañer',
#  'CDLP',
#  'Champion Reverse Weave',
#  'Charles Jeffrey Loverboy',
#  'Chemist Creations',
#  'Chen Peng',
#  'Children of the Discordance',
#  'Chin Teo',
#  'Christian Dada',
#  'Christian Louboutin',
#  'Clarks Originals',
#  'Clot',
#  'CMMN SWDN',
#  'Coach 1941',
#  'Cobra S.C.',
#  'Colmar by White Mountaineering',
#  'COMMAS',
#  'Comme des Garçons Homme',
#  'Comme des Garçons Homme Deux',
#  'Comme des Garçons Homme Plus',
#  'Comme des Garçons Play',
#  'Comme des Garçons Shirt',
#  'Comme des Garçons Wallets',
#  'Common Projects',
#  'Converse',
#  'Cornerstone',
#  'Côte & Ciel',
#  'Cottweiler',
#  'Craig Green',
#  'Cutler And Gross',
#  'D.Gnak by Kang.D',
#  "D'heygere",
#  'Daniel W. Fletcher',
#  'Davi Paris',
#  'Dear Letterman',
#  'Deepti',
#  'Descente Allterrain',
#  'Deveaux New York',
#  'Dickies Construct',
#  'Diemme',
#  'Diesel',
#  'Diesel Red Tag',
#  'Dion Lee',
#  'Dior Homme',
#  'District Vision',
#  'Dita',
#  'Dolce & Gabbana',
#  'DOPPIAA',
#  'Double Rainbouu',
#  'Doublet',
#  'Dr. Martens',
#  "Drake's",
#  'Dries Van Noten',
#  'Dsquared2',
#  'Dunhill',
#  'Eastpak',
#  'Eastwood Danso',
#  'Eckhaus Latta',
#  'EDEN power corp',
#  'Eidos',
#  'Emanuele Bicocchi',
#  'Endless Joy',
#  'Enfants Riches Déprimés',
#  'Engineered Garments',
#  'ERL',
#  'Ermenegildo Zegna',
#  'ermenegildo zegna couture',
#  'Essentials',
#  'Etro',
#  'Études',
#  'Everest Isles',
#  'Eytys',
#  'Faith Connexion',
#  'Fear of God',
#  'Fear of God Ermenegildo Zegna',
#  'Feit',
#  'Fendi',
#  'Feng Chen Wang',
#  'Filling Pieces',
#  'Frame',
#  'FREI-MUT',
#  'Frenckenberger',
#  'Fumito Ganryu',
#  'Garrett Leight',
#  'GCDS',
#  'Gentle Monster',
#  'Georges Wendell',
#  'Georgia Kemball',
#  'Giorgio Armani',
#  'Giuseppe Zanotti',
#  'Givenchy',
#  'GmbH',
#  'Golden Goose',
#  'Goldwin',
#  'Goodfight',
#  'GR-Uniforma',
#  'GR10K',
#  'Greg Lauren',
#  'Grey Ant',
#  'Gucci',
#  'Guidi',
#  'Haider Ackermann',
#  'Han Kjobenhavn',
#  'Harmony',
#  'Harris Wharf London',
#  'Hatton Labs',
#  'Hed Mayner',
#  'HELIOT EMIL',
#  'Helmut Lang',
#  'Herno',
#  'Heron Preston',
#  'Hoka One One',
#  'Holubar',
#  'Homme Plissé Issey Miyake',
#  'Honey Fucking Dijon',
#  'HOPE',
#  'House of the Very Islands',
#  'Hugo',
#  'Human Recreational Services',
#  'Husbands',
#  'Hyein Seo',
#  'IN GOLD WE TRUST PARIS',
#  'Innerraum',
#  'Instrmnt',
#  'ION',
#  'Isabel Benenato',
#  'Isabel Marant',
#  'Issey Miyake Men',
#  'Jacquemus',
#  'JACQUES',
#  'Jan-Jan Van Essche',
#  'JERIH',
#  'Jil Sander',
#  'Jiye Shin',
#  'John Elliott',
#  'Johnlawrencesullivan',
#  'Joseph',
#  'Judy Turner',
#  'Julius',
#  'Junghans',
#  'Junya Watanabe',
#  'Juun.J',
#  'JW Anderson',
#  'Kanghyuk',
#  'Kanuk',
#  'Kara',
#  'KASSL Editions',
#  'Keenkee',
#  'Kenzo',
#  'Kids Worldwide',
#  'Kiko Kostadinov',
#  'Klättermusen',
#  'Ksubi',
#  'Kuboraum',
#  'Kuro',
#  "L'Homme Rouge",
#  'Lacoste',
#  'Landlord',
#  'Lanvin',
#  'Le Gramme',
#  'Lemaire',
#  'Les Tien',
#  "Levi's",
#  "Levi's Made & Crafted",
#  "Levi's Vintage Clothing",
#  'Li-Ning',
#  'Liam Hodges',
#  'Linda Farrow Luxe',
#  'Linder',
#  'Loewe',
#  'LQQK Studio for Paul & Shark',
#  'Ludovic de Saint Sernin',
#  'Mackage',
#  'Mackintosh',
#  'Maison Kitsuné',
#  'Maison Margiela',
#  'Malibu Sandals',
#  'Marc Jacobs',
#  'Marcelo Burlon County of Milan',
#  'Marine Serre',
#  'Marni',
#  'Marsèll',
#  'Martin Asbjorn',
#  'Martine Ali',
#  'Martine Rose',
#  'Martyre',
#  'Master & Dynamic',
#  'Master-Piece Co',
#  'mastermind JAPAN',
#  'mastermind WORLD',
#  'Matsuda',
#  'Matthew Adams Dolan',
#  'Maurice Lacroix',
#  'Maximum Henry',
#  'MCQ',
#  'McQ Alexander McQueen',
#  'mfpen',
#  'Miharayasuhiro',
#  'Minotaur',
#  'MISBHV',
#  'Missoni',
#  'Molly Goddard',
#  'Moncler',
#  'Moncler Genius',
#  'Moncler Grenoble',
#  'More Joy',
#  'Moschino',
#  'Moussy Vintage',
#  'Mowalola',
#  'Mr & Mrs Italy',
#  'Mr. Saturday',
#  'MSGM',
#  'Mugler',
#  'Museum of Peace & Quiet',
#  'Mykita',
#  'N.Hoolywood',
#  'Nahmias',
#  'Naked & Famous Denim',
#  'Namacheko',
#  'Name.',
#  'NAMESAKE',
#  'Nanamica',
#  'Nanushka',
#  'NAPA by Martine Rose',
#  'Nasaseasons',
#  'Native Sons',
#  'Needles',
#  'Neighborhood',
#  'Neil Barrett',
#  'NEMEN®',
#  'New Balance',
#  'Nicholas Daley',
#  'Nike',
#  'Nike ACG',
#  'Noah',
#  'Nobis',
#  'Nomenklatura Studio',
#  'nonnative',
#  'Noon Goons',
#  'Norse Projects',
#  'Nudie Jeans',
#  'Oakley by Samuel Ross',
#  'OAMC',
#  'Off-White',
#  'Officine Creative',
#  'Officine Générale',
#  'Oliver Peoples',
#  'Oliver Peoples The Row',
#  'On',
#  'Onia',
#  'Opening Ceremony',
#  'Ottolinger',
#  'Our Legacy',
#  'paa',
#  'Paco Rabanne',
#  'Palm Angels',
#  'Palomo Spain',
#  'Parajumpers',
#  'paria /FARZANEH',
#  'Paul Smith',
#  'Paul Smith + Christoph Niemann',
#  'Paul Smith 50th Anniversary',
#  'Paul Smith by Mark Mahoney',
#  'Pearls Before Swine',
#  'Perks and Mini',
#  'Persol',
#  'Phipps',
#  'Phlemuns',
#  'Pierre Hardy',
#  "Poggy's Box",
#  'Polo Ralph Lauren',
#  'Polythene* Optics',
#  'Port Tanger',
#  'Post Archive Faction (PAF)',
#  "PRESIDENT's",
#  'PS by Paul Smith',
#  'Pyer Moss',
#  'R.M. Williams',
#  'R13',
#  'RAEN',
#  'Raf Simons',
#  'rag & bone',
#  'Ralph Lauren Purple Label',
#  'Random Identities',
#  'Rassvet',
#  'Ray-Ban',
#  'Re/Done',
#  'Reebok by Pyer Moss',
#  'Reebok Classics',
#  'Reese Cooper',
#  'Remi Relief',
#  'Resort Corps',
#  'RETROSUPERFUTURE',
#  'Rhude',
#  'Rick Owens',
#  'Rick Owens Drkshdw',
#  'RLX Ralph Lauren',
#  'ROA',
#  'Robert Geller',
#  'Rochambeau',
#  'Rochas Homme',
#  'ROGIC',
#  'Rombaut',
#  'RRL',
#  'S.R. STUDIO. LA. CA.',
#  'Sacai',
#  'Saint Laurent',
#  'Saintwoods',
#  'Salomon',
#  'Salvatore Ferragamo',
#  'Sankuanz',
#  'Sasquatchfabrix.',
#  'Satisfy',
#  'Saturdays NYC',
#  'Saul Nash',
#  "Schnayderman's",
#  'Schott',
#  'Sean Suen',
#  'Second/Layer',
#  'Séfr',
#  'Serapis',
#  'Shinola',
#  'Sies Marjan',
#  'Smythson',
#  'Snow Peak',
#  'Soar Running',
#  'Solid & Striped',
#  'Solid Homme',
#  'Song for the Mute',
#  'South2 West8',
#  'Spalwart',
#  'Spencer Badu',
#  'Sporty & Rich',
#  'SSS World Corp',
#  'St-Henri',
#  'Stand Studio',
#  'Stay Made',
#  'Stefan Cooke',
#  'Stella McCartney',
#  'Stolen Girlfriends Club',
#  'Stone Island',
#  'Stone Island Shadow Project',
#  'Studio Nicholson',
#  'Stüssy',
#  'Stutterheim',
#  'SUBU',
#  'Suicoke',
#  'Sulvam',
#  'Sunflower',
#  'Sunnei',
#  'Sunspel',
#  'SWEETLIMEJUICE',
#  'System',
#  'TAION',
#  'TAKAHIROMIYASHITA TheSoloist.',
#  'Tanaka',
#  'Tekla',
#  'Telfar',
#  'Ten c',
#  'The Elder Statesman',
#  'The Row',
#  'The Very Warm',
#  'The Viridi-anne',
#  'Thierry Lasry',
#  'thisisneverthat',
#  'Thom Browne',
#  'Tibi',
#  'Tiger of Sweden',
#  'Tiger of Sweden Jeans',
#  'Toga',
#  'Toga Virilis',
#  'Tom Ford',
#  'Tom Wood',
#  'Toogood',
#  'Total Luxury Spa',
#  'ts(s)',
#  'Ugo Cacciatori',
#  'Undercover',
#  'UNIFORME',
#  'Unravel',
#  'Valentino',
#  'Vans',
#  'Veilance',
#  'Vejas',
#  'Versace',
#  'Versace Jeans Couture',
#  'Versace Underwear',
#  'Versus',
#  'VETEMENTS',
#  'Virón',
#  'Visvim',
#  'VIU',
#  'Vivienne Westwood',
#  'Vyner Articles',
#  'WACKO MARIA',
#  'Wales Bonner',
#  'We11done',
#  'Western Hydrodynamic Research',
#  'Who Decides War by MRDR BRVDO',
#  'Winnie New York',
#  'Wonders',
#  'Wood Wood',
#  'Woolrich',
#  'Wooyoungmi',
#  'Worstok',
#  'WWW.WILLSHOTT',
#  'Xander Zhou',
#  'Y-3',
#  'Y/Project',
#  'Yang Li',
#  'Yohji Yamamoto',
#  'Youths in Balaclava',
#  'Yves Salomon',
#  'Yves Salomon - Army',
#  'Z Zegna',
#  'Ziggy Chen']

# %% [markdown]
# ### 4. MyTheresa

# %%
#Mytheresa | https://www.mytheresa.com/ko-kr/men.html
mytheresa_brand = []

options = wb.ChromeOptions()
options.add_argument('headless')
options.add_argument('window-size=1920x1080')
options.add_argument("disable-gpu")
driver = wb.Chrome('C:/Users/kion9/Desktop/2020-2학기/웹파이썬프로그래밍/term_project/chromedriver',chrome_options=options)
driver.implicitly_wait(3)
driver.get("https://www.mytheresa.com/ko-kr/men/designers.html")
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

brands = soup.find_all('p')
for b in brands:
    brand = b.get_text().strip().replace('\xa0new','')
    brand = brand.replace('\xa0coming soon','')
    mytheresa_brand.append(brand)

start_index = mytheresa_brand.index('1017 ALYX 9SM')

for i in range(start_index):
    del mytheresa_brand[0]
    
for j in range(4):
    del mytheresa_brand[-1]
'''  
for index in range(len(mytheresa_brand)):
    if('\xa0new' in mytheresa_brand[index]):
        mytheresa_brand[index].replace('xa0new','')
        '''
mytheresa_brand = list(filter(None, mytheresa_brand)) # 빈 분자열 제거

print(mytheresa_brand)
# Out:
# ['1017 ALYX 9SM', 'A-Cold-Wall*', 'Acne Studios', 'Adidas Originals', 'Alanui', 'Alexander McQueen', 'All Blues', 'Ami', 'Amiri', 'And Wander new', 'Asics', 'Athletics Footwear', 'Auralee', 'Axel Arigato', 'Aztech Mountain', 'Balenciaga', 'Balmain', 'Barena Venezia', 'Berluti new', 'Birkenstock', 'Bode', 'Bogner', 'Borsalino', 'Bottega Veneta', 'Brunello Cucinelli', 'Burberry', 'Canada Goose', 'Cartier Eyewear Collection', 'Caruso', 'Casablanca', 'Celine Eyewear', 'Christian Louboutin new', "Church's", 'Clarks new', 'Commas', 'Comme des Garçons Homme', 'Common Projects', 'Craig Green', 'Derek Rose', 'Dior Eyewear', 'Dolce & Gabbana', 'Dries Van Noten', 'Éditions M.R', 'ELHANATI', 'ERL', 'Ermenegildo Zegna', 'Etro', 'Fendi', 'Frescobol Carioca', 'Fusalp', 'Gabriela Hearst', 'Gianvito Rossi', 'Givenchy', 'Golden Goose', 'GR10K', 'Gucci', 'Harris Wharf London', 'Herno new', 'Hoka One One', 'Incotex', 'Isabel Marant new', 'Jacquemus', 'Jil Sander', 'John Lobb', 'John Smedley', 'Junya Watanabe', 'JW Anderson', 'King & Tuckfield', 'KJUS', 'Lanvin', 'Lardini', 'Lemaire', 'Les Tien', 'Loewe', 'Loro Piana', 'Mackintosh', 'Maison Margiela', 'Marni', 'Missoni', 'Moncler', 'Moncler Genius', 'Moncler Grenoble', 'Nanushka', 'Nike', 'OAMC', 'Officine\xa0Générale', 'Off-White', 'Orlebar Brown', 'Our\xa0Legacy', 'Phipps', 'Polo Ralph Lauren', 'Raf Simons', 'Ralph Lauren Purple Label', 'Reebok', 'Rick Owens', 'Rochas', 'RRL', 'Sacai', 'Saint Laurent', 'Salomon', 'Santoni', 'Satisfy', 'Sease', 'Stella McCartney', 'Stone Island new', 'Sunspel', 'The Elder Statesman', 'The Gigi', 'The North Face', 'The North Face Black Series', 'Thom Browne', 'Thom Sweeney', "Tod's", 'Tom Ford', 'Tom Wood', 'Toni Sailer', 'Undercover', 'Valentino', 'Veja', 'Versace', 'Vilebrequin', 'Visvim', 'Wales Bonner', 'Wardrobe.NYC', 'Winnie NYC', 'Zanone']

# %% [markdown]
# ### 5. END clothing

# %%
#END | https://www.endclothing.com/kr
end_brand =[]

options = wb.ChromeOptions()
options.add_argument('headless')
options.add_argument('window-size=1920x1080')
options.add_argument("disable-gpu")
driver = wb.Chrome('C:/Users/kion9/Desktop/2020-2학기/웹파이썬프로그래밍/term_project/chromedriver',chrome_options=options)
driver.implicitly_wait(3)
driver.get("https://www.endclothing.com/kr/brands")
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

brands = soup.find_all('a', class_ = 'Link__InnerLink-e4qf6g-0 fyNuGQ LetterBrandsSection__BrandLinkSC-sc-1hk2oim-4 koSxWv')
for brand in brands:
    b = brand.get_text()
    end_brand.append(b)
    
print(end_brand)
# Out:
# ['032c', '1017 ALYX 9SM', '1882', '19-69', '24 Bottles', '424', '4SDESIGNS', 'A Bathing Ape', 'A Bathing Ape Eyewear', 'A Bathing Ape Kids', 'A Kind of Guise', 'A-COLD-WALL*', 'A.P.C.', 'AAPE by A Bathing Ape', 'Acne Studios', 'Acne Studios Mini', 'Acqua Di Parma', 'ADER error', 'adidas', 'adidas Consortium', 'adidas Spezial', 'adidas Terrex', 'adidas Womens', 'ADISH', 'Adsum', 'Aesop', 'AFFIX', 'AIAIAI', 'Aimé Leon Dore', "Aitor Throup's TheDSA", 'AKILA', 'Alanui', 'Albam', 'Alden Shoe Company', 'Alexander McQueen', 'Alexander Wang', 'Alife', 'All Blues', 'Alltimers', 'Alpha Industries', 'AMBUSH', 'AMI', 'AMIRI', 'And Wander', "Anderson's", 'Anglepoise', 'Anonymous Ism', "Arc'teryx", 'Aries', 'Ark Air', 'Armor-Lux', 'Arpenteur', 'Artek', 'Artifact by Superga', 'Asics', 'Assid', 'Astorflex', 'Athletics Footwear', 'Attirecare', 'Axel Arigato', 'Ayamé Socks', 'B&O PLAY by Bang & Olufsen', 'Balenciaga', 'Balmain', 'Baracuta', 'Barbour', 'Barena', 'Battenwear', 'Baxter of California', 'Beams Plus', 'Belstaff', 'Billionaire Boys Club', 'Birkenstock', 'Bleu de Paname', 'Bleue Burnham', 'Blue Blue Japan', 'Boiler Room', 'BORNN', 'Bounty Hunter', 'Brain Dead', 'Brandblack', 'Braun', 'Bronze 56k', 'Burberry', 'Buttero', 'By Parra', 'Byredo', 'C.P. Company', 'C.P. Company Undersixteen', 'C6', 'Calvin Klein', 'Calvin Klein 205W39NYC', 'Canada Goose', 'Cape Heights', 'Carhartt WIP', 'Casablanca', 'Cav Empt', 'CDLP', 'CELINE', 'Chaco', 'Champion Reverse Weave', 'Champion Reverse Weave Womens', 'Chamula', 'Chinatown Market', 'CHUP by Glen Clyde Company', "Church's", 'Ciele Athletics', 'Clarks Originals', 'CLOT', 'Coach', 'Cole Buxton', 'Colorful Standard', 'Columbia', 'Comme des Garçons', 'Comme des Garçons Black', 'Comme des Garçons Homme', 'Comme des Garçons Homme Plus', 'Comme des Garçons Parfums', 'Comme des Garçons Play', 'Comme des Garçons Play Kids', 'Comme des Garçons SHIRT', 'Comme des Garçons Wallets', 'Common Projects', 'Compagnie de Provence', 'Converse', 'Corridor', 'Cote&Ciel', 'Cotopaxi', 'Craig Green', 'Crep Protect', 'Crocs', 'Cubitts', 'D.R. Harris & Co.', 'Danner', 'Danton', 'DENHAM', 'Descente Allterrain', 'Diadora', 'Dickies', 'Diemme', 'Dime', 'Dior Eyewear', 'Dior Homme', 'Dita', "Dr. Jackson's Natural Products", 'Dr. Martens', 'Druthers', 'Drôle de Monsieur', 'Dusen Dusen', 'Eastpak', 'Ebbets Field Flannels', 'Edifice', 'Edwin', 'END.', 'Engineered Garments', 'Engineered Garments Workaday', 'Epperson Mountaineering', 'Escentric Molecules', 'ETQ. Amsterdam', 'Eytys', 'F.C. Real Bristol', 'Falcon Enamelware', 'FDMTL', 'Fear of God', 'Fear of God ESSENTIALS', 'Fear of God x Zegna', 'Ferm Living', 'Filling Pieces', 'Filson', 'First Arrows', 'Fjällräven', 'Flagstuff', 'Flatlist', 'Floyd', 'Folk', 'Fracap', 'Frama', 'Fred Perry', 'Fred Perry x Raf Simons', 'Fucking Awesome', 'Futur', 'G-Shock', 'Garrett Leight', 'Gentle Monster', 'Gitman Vintage', 'Givenchy', 'Golden Goose Deluxe Brand', 'GR Uniforma', 'Gramicci', 'Grenson', 'Grown Alchemist', 'Gucci', 'Gucci Eyewear', 'Haeckels', 'Han Kjobenhavn', 'Harmony', 'Hartford', 'Hatton Labs', 'HAVEN', 'HAY', 'Helinox', 'Helmut Lang', 'Hender Scheme', 'Heresy', 'Heron Preston', 'Hestra', 'Hikerdelic', 'Hilfiger Collection', 'hobo', 'Hoka One One', 'Honey Fucking Dijon', 'Horizn Studios', "Howlin'", 'Human Made', 'Hydroflask', 'IDEA', 'Ignored Prayers', 'Imperial Barbershop Products', 'Incotex', 'Indispensable', 'Inverallan', 'Jacques Marie Mage', 'JAM', "Jamieson's of Shetland", 'Jason Markk', 'Jil Sander', 'John Elliott', 'Junior Executive', 'Junya Watanabe MAN', 'JW Anderson', 'Kappa Kontroll', 'Karhu', 'KEEN', 'Kenzo', 'KESTIN', 'KINTO', 'Kirk Originals', 'Klean Kanteen', 'Klättermusen', 'Know Wave', 'Krink', 'Ksubi', 'L:A Bruket', 'Laboratory Perfumes', 'Lacoste', 'Lanvin', 'Le Gramme', 'Les Basics', 'Les Tien', 'Levi’s Vintage Clothing', 'Li-Ning', 'Liam Hodges', 'Liberaiders', 'Liquiproof', 'London Undercover', 'Lost Daze', 'M+RC Noir', 'M. Cohen', 'Mackintosh', 'Maharishi', ...

# %% [markdown]
# ### 6. Mr.Porter

# %%
#MrPorter | https://www.mrporter.com/en-kr/
mrporter_brand = []
'''
options = wb.ChromeOptions()
options.add_argument('headless')
options.add_argument('window-size=1920x1080')
options.add_argument("disable-gpu")
'''
driver = wb.Chrome('C:/Users/kion9/Desktop/2020-2학기/웹파이썬프로그래밍/term_project/chromedriver')
driver.implicitly_wait(3)
driver.get("https://www.mrporter.com/en-kr/mens/azdesigners")
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

brandAll = soup.find_all('ul', class_= 'DesignerList5__group')

for brands in brandAll:
    for brand in brands.select('li > a'):
        b = brand.get_text()
        mrporter_brand.append(b)    

print(mrporter_brand)
print(len(mrporter_brand))
# Out:
# ['1017 ALYX 9SM', '11.11/eleven eleven', '111Skin', '120%', '15th Degree', '19-69', '2XU', '4SDesigns', '99%IS-', 'A-COLD-WALL*', 'A.P.C.', 'Abbeyhorn', 'Acne Studios', 'Ader Error', 'adidas Consortium', 'adidas Golf', 'adidas Originals', 'adidas Sport', 'Adsum', 'Aesop', 'AFFIX', 'AG Jeans', 'ahnah', 'Aimé Leon Dore', 'Alanui', 'Albam', 'ALDOMARIACAMILLO', 'Alex Mill', 'Alexander McQueen', 'Alice Made This', 'Allies Of Skin', 'Aloye', 'Altea', 'Álvaro', 'Amalgam Collection', 'AMI PARIS', 'AMIRI', 'Anatomē', 'ANCIENT+BRAVE', 'And Wander', 'Anderson & Sheppard', "Anderson's", 'Angle By Morrama', 'Anon', 'Anonymous ism', 'Anthony', 'APL Athletic Propulsion Labs', "Arc'teryx", 'Aries', 'Armor Lux', 'Asics', 'Aspesi', 'Asprey', 'Assouline', 'Atalaye', 'Augustinus Bader', 'Auralee', 'Aztech Mountain', 'Balenciaga', 'Balmain', 'Bamford Grooming Department', 'Bamford Watch Department', 'Bang & Olufsen', 'Baracuta', 'Barbour Gold Standard', 'Barbour White Label', 'Barena', 'Baume', 'Baume & Mercier', 'Baxter Of California', 'BE@RBRICK', 'Beams', 'Beams F', 'Beams Plus', 'Bellerby & Co Globemakers', 'Bellerose', 'Belstaff', 'Ben Soleimani', 'Bennett Winch', 'Berg & Berg', 'Berluti', 'Best Made Company', 'Bigi', 'Billionaire Boys Club', 'Birdwell', 'Birkenstock', 'Black Crows', 'Blackmeans', 'Bleu de Chauffe', 'Bleue Burnham', 'Blind Barber', 'Blue Blue Japan', 'BODE', 'Bodyism', 'Boglioli', 'Bogner', 'Bolin Webb', 'Borsalino', 'Bottega Veneta', 'Bovet', 'Bowers & Wilkins', 'Breitling', 'Bremont', 'Brioni', 'Brooks England', 'Brunello Cucinelli', 'Buly 1803', 'Bunney', 'Burberry', 'BURTON', 'By Japan', 'C.O. Bigelow', 'C.P. Company', 'Café du Cycliste', 'Café Kitsuné', 'Calvin Klein Underwear', 'Camoshita', 'Canada Goose', 'Canali', "Caran D'Ache", 'Carhartt WIP', 'Cartier', 'Cartier Eyewear', 'Caruso', 'Casablanca', 'Castañer', 'Castore', 'CDLP', 'Celestron', 'CELINE HOMME', 'Champion', 'Charvet', 'Cheaney', 'Chimala', 'Christian Louboutin', 'Christophe Robin', "Church's", 'Cire Trudon', 'Claus Porto', 'Cleverly Laundry', 'Clinique for Men', 'Club Monaco', 'Colmar', 'COME TEES', 'Comme des Garçons', 'Comme des Garçons HOMME', 'Comme des Garçons Parfums', 'Comme des Garçons SHIRT', 'Common Projects', 'Connolly', 'Converse', 'Corgi', 'Craig Green', 'Cubitts', 'Cutler and Gross', 'Czech & Speake', 'D R Harris', 'D.S. and Durga', 'David Yurman', 'De Bonne Facture', 'De Petrillo', 'Deakin & Francis', 'Dents', 'Derek Rose', 'Desmond & Dempsey', 'Deveaux', 'Devialet', 'Dick Moby', 'Diemme', 'District Vision', 'Doers Of London', 'Dolce & Gabbana', 'Dr Sebagh', 'Dr. Barbara Sturm', 'Dr. Dennis Gross Skincare', "Dr. Jackson's", 'Dr. Martens', "Drake's", 'Dries Van Noten', 'Dunhill', 'E.B. Meyrowitz', 'E.MARINELLA', 'Eastpak', 'Edward Green', 'EDWIN', 'EISENBERG PARIS', 'Elemis', 'Emma Willis', 'Endless Joy', 'Enfants Riches Déprimés', 'Engineered Garments', 'Entireworld', 'EQUIPMENT', 'Ermenegildo Zegna', 'Etro', 'Eyevan 7285', 'Faherty', 'Falke', 'Falke Ergonomic Sport System', 'Favourbrook', 'Fear of God', 'Fear of God Essentials', 'Fear of God for Ermenegildo Zegna', 'Fendi', 'Filson', 'Fizik', 'Flagstuff', 'Flatlist', 'Floris London', 'Folk', 'Form Nutrition', 'Fornasetti', 'Foundrae', 'Foundwell', 'FPM Milano', 'Frame', 'Francesco Maglia', 'Frederic Malle', 'Frescobol Carioca', 'FujiFilm', 'Fusalp', 'G.H. Bass & Co.', 'Gabriela Hearst', 'Gallery Dept.', 'Garrett Leight California Optical', 'George Cleverley', 'Giorgio Armani', 'Girard-Perregaux', 'Gitman Vintage', 'Giuliva Heritage', 'Givenchy', 'Globe-Trotter', 'Go Barefoot', 'Golden Bear', 'Golden Goose', 'GOOD ART HLYWD', 'GoPro', 'Graf von Faber-Castell', 'Gramicci', 'Greg Lauren', 'Grenson', 'Grown Alchemist', 'Gucci', 'Hackett', 'Haeckels', 'Hamilton And Hare', 'Hampton Sun', 'Handvaerk', 'Hanro', 'Hanz de Fuko', "Harry's", 'Hartford', 'Heimplanet', 'Hender Scheme', 'Herno', 'Herno Laminar', 'Herschel Supply Co', 'Hestra', 'Hoka One One', 'Holden', 'Horace', 'Horizn Studios', 'Houdini ...
# 645

# %%
matches_brand
farfetch_brand
ssense_brand
mytheresa_brand
end_brand
mrporter_brand
brand_common = list(set(matches_brand) & set(farfetch_brand) & set(ssense_brand) & set(mytheresa_brand) & set(end_brand) & set(mrporter_brand))

brand_common = sorted(brand_common)
brand_set = set(brand_common)
print(brand_common)
# Out:
# ['1017 ALYX 9SM', 'Acne Studios', 'Alexander McQueen', 'Balenciaga', 'Balmain', 'Burberry', 'Canada Goose', 'Casablanca', 'Common Projects', 'Craig Green', 'Givenchy', 'Gucci', 'JW Anderson', 'Mackintosh', 'Maison Margiela', 'Moncler', 'Moncler Grenoble', 'Polo Ralph Lauren', 'Raf Simons', 'Rick Owens', 'Satisfy', 'Sunspel', 'Thom Browne', 'Tom Wood', 'Undercover', 'Valentino', 'Versace']

# %% [markdown]
# 이제 브랜드를 모두 정리했으니 카테고리를 만들 차례이다.

# %% [markdown]
# ## 카테고리 선택 만들기

# %% [markdown]
# https://www.matchesfashion.com/kr/mens/designers/
# https://www.farfetch.com/kr/shopping/men/
# https://www.ssense.com/en-us/men/designers/
# https://www.mytheresa.com/en-kr/men/designers/
# https://www.endclothing.com/kr/
# https://www.mrporter.com/en-kr/mens/designer/

# %% [markdown]
# ## GUI 생성

# %%
import selenium.webdriver.support.ui as ui
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.remote.webelement import WebElement
from selenium.webdriver.common.keys import Keys
from selenium.webdriver import ActionChains

from tkinter import *
from tkinter import ttk

class windows_tkinter:
    def __init__(self, broswer):
        self.browser = browser
        self.browser.title("Your Shopping Host")
        self.browser.geometry("450x200")

        self.var1 = StringVar()
        self.var2 = StringVar()

        self.welc = Label(self.browser, text="Welcome back shopping!\n", font = "BerlinSansFB 20")
        self.welc.grid(row=0, column = 1)

        self.brnd = Label(self.browser, text="Brand", font = "BerlinSansFB 10")
        self.brnd.grid(row=1, column =0)

        self.Combo1 = ttk.Combobox(textvariable = self.var1, width=20,state='readonly')
        self.Combo1['value'] = ('1017 ALYX 9SM', 'Acne Studios', 'Alexander McQueen', 'Balenciaga', 'Balmain', 'Burberry', 'Canada Goose', 'Casablanca', 'Common Projects', 'Craig Green', 'Givenchy', 'Gucci', 'JW Anderson', 'Mackintosh', 'Maison Margiela', 'Moncler', 'Moncler Grenoble', 'Polo Ralph Lauren', 'Raf Simons', 'Rick Owens', 'Satisfy', 'Sunspel', 'Thom Browne', 'Tom Wood', 'Undercover', 'Valentino', 'Versace')
        self.Combo1.current(0)
        self.Combo1.grid(row=1, column=1)
        self.selectedBrand = self.Combo1.get()

        self.ctgry =  Label(self.browser, text="Category", font = "BerlinSansFB 10")
        self.ctgry.grid(row=3, column =0)

        self.Combo2 = ttk.Combobox(textvariable = self.var2, width=20,state='readonly')
        self.Combo2['value'] = ('clothing', 'shoes', 'bags', 'accessories')
        self.Combo2.current(0)
        self.Combo2.grid(row=3, column=1)
        self.selectedCategory = self.Combo2.get()
        self.mAddress_list = ["https://www.matchesfashion.com/kr/mens/designers/","https://www.farfetch.com/kr/shopping/men/","https://www.ssense.com/en-us/men/designers/","https://www.mytheresa.com/en-kr/men/designers/","https://www.mrporter.com/en-kr/mens/designer/"]
        self.__main__()

    def genAddress_and_exe(self):
        self.selectedBrand = self.Combo1.get()
        self.selectedCategory = self.Combo2.get()
        brand = self.selectedBrand.replace(' ', '-')

        for mAddress in self.mAddress_list:
            if(mAddress == "https://www.farfetch.com/kr/shopping/men/"):
                if(self.selectedCategory == 'clothing'):
                    category = "/items.aspx?view=90&category=136330"
                elif(self.selectedCategory == 'bags'):
                    category = "bags-purses-2/items.aspx"
                elif(self.selectedCategory =='shoes'):
                    category = "shoes-2/items.aspx"
                elif(self.selectedCategory =='accessories'):
                    category = "accessories-all-2/items.aspx"
                self.address1 = mAddress + brand + '/'+ category
            elif(mAddress == "https://www.ssense.com/en-us/men/designers/"):
                if(brand == "1017-ALYX-9SM"):
                    brandSsense = "alyx"
                else:
                    brandSsense = str.lower(brand)
                self.address2 = mAddress + brandSsense + '/'+self.selectedCategory    
            elif(mAddress == "https://www.mytheresa.com/en-kr/men/designers/"):
                if(brand == "1017-ALYX-9SM"):
                    brandTheresa = str.lower(brand)
                else:
                    brandTheresa = str.lower(brand)
                self.address3 = mAddress + brandTheresa + '/'+self.selectedCategory + ".html"   
            elif(mAddress == "https://www.mrporter.com/en-kr/mens/designer/"):
                if(self.selectedCategory == "bags"):
                    category = "accessories/bags"
                else:
                    category = self.selectedCategory
                self.address4 = mAddress + brand + '/'+ category
            else:
                self.address5 = mAddress + brand + '/'+ self.selectedCategory
   
        CHROMEDRIVER_PATH = './chromedriver.exe'
        chrome_options = Options()
        chrome_options.add_argument('--start-maximized')
        chrome_options.add_argument("--disable-infobars")

        #브라우저 실행 및 탭 추가
        driver = webdriver.Chrome( executable_path=CHROMEDRIVER_PATH, chrome_options=chrome_options )
        driver.execute_script('window.open("about:blank", "_blank");')
        driver.execute_script('window.open("about:blank", "_blank");')
        driver.execute_script('window.open("about:blank", "_blank");')
        driver.execute_script('window.open("about:blank", "_blank");')

        tabs = driver.window_handles

        # TAB_1
        driver.switch_to_window(tabs[0])
        driver.get(self.address1)

        # TAB_2
        driver.switch_to_window(tabs[1])
        driver.get(self.address2)

        # TAB_3
        driver.switch_to_window(tabs[2])
        driver.get(self.address3)

        # TAB_4
        driver.switch_to_window(tabs[3])
        driver.get(self.address4)

        # TAB_5
        driver.switch_to_window(tabs[4])
        driver.get(self.address5)


    def __main__(self):
        bttn = Button(self.browser, text = "Browse!",command=lambda:self.genAddress_and_exe())
        bttn.grid(row=4, column = 1)

if __name__ == '__main__':    
    browser = Tk()
    windows_tkinter(browser)
    browser.mainloop()
